# %% [markdown]
# # Learn Python From Zero For Absolute Beginner (1): Data Cleaning

# %% [markdown]
# Welcome to our first lesson of the "Learn Python From Zero For Absolute Beginner" series!
#
# Here, you'll find the completed full code for the task at hand. However, if you're looking for a more detailed understanding and want to **follow along step by step with thorough explanations**, we highly recommend you to read our article below:
#
#  👉 https://digitalhumanities.hkust.edu.hk/tutorials/learn-python-from-zero-for-absolute-beginner-1-data-cleaning/
#
# The article provides comprehensive explanations and instructions that will help you grasp the underlying concepts.

# %% [markdown]
# ---

# %% [markdown]
# ## Install Python libraries

# %% [markdown]
# ### Method 1

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# ### Method 2

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# ---

# %% [markdown]
# ## Import Python libraries

# %%
import pandas as pd

# %% [markdown]
# ---

# %% [markdown]
# ## Import data from Excel

# %% [markdown]
# Click [here](https://bit.ly/hkust-dh-github-data-threadbound) to download the Excel file `data_dh-tutorial_rse-ChiBksBefore1949-ThreadBound.xlsx` and upload it to your Google Drive.

# %%
# Change the filepath according to your file location
filepath = '/content/drive/MyDrive/Colab Notebooks/data/data_dh-tutorial_rse-ChiBksBefore1949-ThreadBound.xlsx'

# %%
data = pd.read_excel(filepath, sheet_name='rawdata')

# %%
# preview
data
# Out:
#     Year published
# 0          1600(1)
# 1          1655(1)
# 2          1705(1)
# 3          1709(1)
# 4          1748(1)
# ..             ...
# 101       1945(10)
# 102        1946(4)
# 103        1947(5)
# 104        1948(6)
# 105        1949(3)
#
# [106 rows x 1 columns]

# %%
# preview the first few rows (default as 5)
data.head()
# Out:
#   Year published
# 0        1600(1)
# 1        1655(1)
# 2        1705(1)
# 3        1709(1)
# 4        1748(1)

# %%
# preview the first 8 rows
data.head(8)
# Out:
#   Year published
# 0        1600(1)
# 1        1655(1)
# 2        1705(1)
# 3        1709(1)
# 4        1748(1)
# 5        1749(1)
# 6        1781(1)
# 7        1786(1)

# %%
# preview the last few rows (default as 5)
data.tail()
# Out:
#     Year published
# 101       1945(10)
# 102        1946(4)
# 103        1947(5)
# 104        1948(6)
# 105        1949(3)

# %% [markdown]
# ---

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Split one column to multiple columns according to special character

# %%
data[['year','number of items']] = data['Year published'].str.split('(',expand=True)

# %%
# preview
data.head()
# Out:
#   Year published  year number of items
# 0        1600(1)  1600              1)
# 1        1655(1)  1655              1)
# 2        1705(1)  1705              1)
# 3        1709(1)  1709              1)
# 4        1748(1)  1748              1)

# %% [markdown]
# ---

# %% [markdown]
# ### Remove columns

# %%
data = data.drop(columns=['Year published'])

# %%
# preview
data.head()
# Out:
#    year number of items
# 0  1600              1)
# 1  1655              1)
# 2  1705              1)
# 3  1709              1)
# 4  1748              1)

# %% [markdown]
# ---

# %% [markdown]
# ### Replace specific character

# %%
data['number of items'] = data['number of items'].str.replace(')','')
# Out:
# <ipython-input-14-4077daa5068f>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['number of items'] = data['number of items'].str.replace(')','')

# %%
# preview
data.head()
# Out:
#    year number of items
# 0  1600               1
# 1  1655               1
# 2  1705               1
# 3  1709               1
# 4  1748               1

# %% [markdown]
# ---

# %% [markdown]
# ### Check whether there is missing value

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             106 non-null    object
#  1   number of items  106 non-null    object
# dtypes: object(2)
# memory usage: 1.8+ KB

# %% [markdown]
# ### Change the data type of the column

# %%
data['number of items'] = data['number of items'].astype('int')
data['year'] = data['year'].astype('int')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             106 non-null    int64
#  1   number of items  106 non-null    int64
# dtypes: int64(2)
# memory usage: 1.8 KB

# %% [markdown]
# ---

# %% [markdown]
# ### Descriptive statistics (get max and min values)

# %%
data.describe()
# Out:
#               year  number of items
# count   106.000000       106.000000
# mean   1880.386792         6.377358
# std      61.890313         9.737950
# min    1600.000000         1.000000
# 25%    1854.750000         1.000000
# 50%    1895.500000         3.000000
# 75%    1922.750000         7.000000
# max    1949.000000        56.000000

# %%
data.describe().round(1)
# Out:
#          year  number of items
# count   106.0            106.0
# mean   1880.4              6.4
# std      61.9              9.7
# min    1600.0              1.0
# 25%    1854.8              1.0
# 50%    1895.5              3.0
# 75%    1922.8              7.0
# max    1949.0             56.0

# %% [markdown]
# ### Get the row of maximum value (loc, idxmax)

# %%
yearMaxItems = data.loc[data['number of items'].idxmax()]

# %% [markdown]
# Let's break down the code and understand its functionality:

# %%
print(data['number of items'].idxmax())
# Out:
# 42

# %%
print(data.loc[42])
# Out:
# year               1884
# number of items      56
# Name: 42, dtype: int64

# %%
yearMaxItems
# Out:
# year               1884
# number of items      56
# Name: 42, dtype: int64

# %%
print(yearMaxItems[0])
# Out:
# 1884

# %%
print(yearMaxItems[1])
# Out:
# 56

# %% [markdown]
# ---

# %% [markdown]
# ### Concatenation (combine string and variables)

# %%
print(data['number of items'].sum())
# Out:
# 676

# %%
sumvalue = data['number of items'].sum()

# %%
print('There are a total of ', sumvalue, ' items in this collection.')
# Out:
# There are a total of  676  items in this collection.

# %%
print('There are a total of ' + str(sumvalue) + ' items in this collection.')
# Out:
# There are a total of 676 items in this collection.

# %%
print(f'There are a total of {sumvalue} items in this collection.')
# Out:
# There are a total of 676 items in this collection.

# %%
print(f'Maximum: In this collection, there are {yearMaxItems[1]} items that were published in {yearMaxItems[0]}.')
# Out:
# Maximum: In this collection, there are 56 items that were published in 1884.

# %% [markdown]
# ---

# %% [markdown]
# ### Assign labels to new column according to conditions (for loops, if...else)

# %% [markdown]
# #### Method 1
#
# Create a function, use `for` loop and `if...elif...else` statement

# %%
# create a function called "grouped_year"
def grouped_year(year):
  if 1501 <= year <= 1600:     # if the value of year is larger than or equal to 1501 AND smaller than or equal to 1600
    return "16th century"      # then, assign "16th century" to the "Period" column for this row
  elif 1601 <= year <= 1700:
    return "17th century"
  elif 1701 <= year <= 1800:
    return "18th century"
  elif 1801 <= year <= 1900:
    return "19th century"
  elif 1901 <= year <= 2000:
    return "20th century"
  else:
    return "Ungrouped"         # in case any values fall outside the above scope, show "Ungrouped" in the "Period" column for this row

# %%
# make a copy of the original dataframe "data", and named the copy as "data1"
data1 = data.copy()

# %%
data1["Period"] = data["year"].apply(lambda year: grouped_year(year))

# %%
# preview
data1
# Out:
#      year  number of items        Period
# 0    1600                1  16th century
# 1    1655                1  17th century
# 2    1705                1  18th century
# 3    1709                1  18th century
# 4    1748                1  18th century
# ..    ...              ...           ...
# 101  1945               10  20th century
# 102  1946                4  20th century
# 103  1947                5  20th century
# 104  1948                6  20th century
# 105  1949                3  20th century
#
# [106 rows x 3 columns]

# %%
# the "data" dataframe will not be affected
data
# Out:
#      year  number of items
# 0    1600                1
# 1    1655                1
# 2    1705                1
# 3    1709                1
# 4    1748                1
# ..    ...              ...
# 101  1945               10
# 102  1946                4
# 103  1947                5
# 104  1948                6
# 105  1949                3
#
# [106 rows x 2 columns]

# %% [markdown]
# #### Method 2
#
# Use 1 line of code

# %%
# make a copy of the original dataframe "data", and named the copy as "data2"
data2 = data.copy()

# %%
data2['Period'] = ['16th century' if 1501 <= year <= 1600 else '17th century' if 1601 <= year <= 1700 else '18th century' if 1701 <= year <= 1800 else '19th century' if 1801 <= year <= 1900 else '20th century' if 1901 <= year <= 2000 else "Ungrouped" for year in data['year']]

# %%
# preview
data2
# Out:
#      year  number of items        Period
# 0    1600                1  16th century
# 1    1655                1  17th century
# 2    1705                1  18th century
# 3    1709                1  18th century
# 4    1748                1  18th century
# ..    ...              ...           ...
# 101  1945               10  20th century
# 102  1946                4  20th century
# 103  1947                5  20th century
# 104  1948                6  20th century
# 105  1949                3  20th century
#
# [106 rows x 3 columns]

# %%
# the "data" dataframe will not be affected
data
# Out:
#      year  number of items
# 0    1600                1
# 1    1655                1
# 2    1705                1
# 3    1709                1
# 4    1748                1
# ..    ...              ...
# 101  1945               10
# 102  1946                4
# 103  1947                5
# 104  1948                6
# 105  1949                3
#
# [106 rows x 2 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Group data (similar to pivot table in Excel)

# %%
# make a copy of the dataframe "data2", and named the copy as "data_r1"
data_r1 = data2.copy()

# %%
# find the number of distinct year in each period
data_r1 = data_r1.groupby('Period')['year'].count().reset_index()

# rename the column "year" to "distinct year"
data_r1.rename(columns={'year':'distinct year'}, inplace=True)

# %%
# preview
data_r1
# Out:
#          Period  distinct year
# 0  16th century              1
# 1  17th century              1
# 2  18th century              8
# 3  19th century             48
# 4  20th century             48

# %%
# make a copy of the dataframe "data2", and named the copy as "data_r2"
data_r2 = data2.copy()

# %%
# find the sum of number of items in each period
data_r2 = data_r2.groupby('Period')['number of items'].sum().reset_index()

# %%
# preview
data_r2
# Out:
#          Period  number of items
# 0  16th century                1
# 1  17th century                1
# 2  18th century                8
# 3  19th century              218
# 4  20th century              448

# %% [markdown]
# ---

# %% [markdown]
# ### Merge two tables/dataframes

# %%
# Merge two DataFrame based on a particular column
data_r_merge = pd.merge(data_r1, data_r2, on='Period')

# %%
# preview
data_r_merge
# Out:
#          Period  distinct year  number of items
# 0  16th century              1                1
# 1  17th century              1                1
# 2  18th century              8                8
# 3  19th century             48              218
# 4  20th century             48              448

# %% [markdown]
# # Next article: Data Visualization
#
# Moving forward, we invite you to join us in our next article, where we will embark on the journey into the realm of data visualization. Together, we will explore the powerful capabilities of Python for creating interactive charts and graphs. These visualizations will enable you to gain deeper insights into your data.
#
# 👉 https://digitalhumanities.hkust.edu.hk/tutorials/learn-python-from-zero-for-absolute-beginner-2-data-visualization/
